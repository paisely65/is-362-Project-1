# %% [markdown]
# # IS 362 Week 5 Assignment
# February 25, 2017
#
# * **Data Dictionary**: https://cran.r-project.org/web/packages/nycflights13/nycflights13.pdf
# * **airports.csv**: http://bit.ly/us_airports
# * **weather.csv**: https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/weather.csv

# %% [markdown]
#  ## What is the northernmost airport in the U.S.?

# %%
import pandas as pd
airports = pd.read_csv("http://bit.ly/us_airports")
airports.head()
airports.sort_values("lat", ascending=False).head(8)
# Out:
#       faa                                        name        lat         lon  \
# 393   EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 217   BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 98    AIN                          Wainwright Airport  70.638056 -159.994722
# 674   K03                               Wainwright As  70.613378 -159.860350
# 140   ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
# 1306  UUK                        Ugnu-Kuparuk Airport  70.330833 -149.597500
# 936   NUI                             Nuiqsut Airport  70.210000 -151.005556
# 1144  SCC                                   Deadhorse  70.194750 -148.465167
#
#       alt  tz dst
# 393   149  -5   A
# 217    44  -9   A
# 98     41  -9   A
# 674    35  -9   A
# 140    96  -9   A
# 1306   67  -9   A
# 936    38  -9   A
# 1144   64  -9   A

# %% [markdown]
# ## What is the easternmost airport in the U.S.?

# %%
airports.sort_values("lon", ascending=False)
# Out:
#       faa                                    name        lat         lon  \
# 1237  SYA                            Eareckson As  52.712275  174.113620
# 897   MYF                        Montgomery Field  32.475900  117.759000
# 372   DVT           Deer Valley Municipal Airport  33.411700  112.457000
# 393   EEN                 Dillant Hopkins Airport  72.270833   42.898333
# 419   EPM              Eastport Municipal Airport  44.910111  -67.012694
# 591   HUL                            Houlton Intl  46.123083  -67.792056
# 246   CAR                            Caribou Muni  46.871500  -68.017917
# 1052  PQI     Northern Maine Rgnl At Presque Isle  46.688958  -68.044797
# 1340  WFK     Northern Aroostook Regional Airport  47.285556  -68.312778
# 180   BHB             Hancock County - Bar Harbor  44.449769  -68.361565
# 815   ME5                           Banks Airport  44.165389  -68.428167
# 852   MLT                        Millinocket Muni  45.647836  -68.685561
# ...

# %% [markdown]
# ## On February 12th, 2013, which New York area airport had the windiest weather?

# %%
speed = pd.read_csv("https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/weather.csv")
speed.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib             time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01T00:00:00Z
# 1  15.891535     0.0    1013.0   10.0  2013-01-01T01:00:00Z
# 2  14.567241     0.0    1012.6   10.0  2013-01-01T02:00:00Z
# 3  15.891535     0.0    1012.7   10.0  2013-01-01T03:00:00Z
# 4  17.215830     0.0    1012.8   10.0  2013-01-01T04:00:00Z

# %%
speed.sort_values("wind_speed", ascending=False)
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1015     EWR  2013      2   12     8  39.02  26.96  61.63     260.0
# 9436     JFK  2013      1   31     9  53.60  51.80  93.60     200.0
# 728      EWR  2013      1   31     9  60.80  59.00  93.79     230.0
# 18147    LGA  2013      1   31     9  57.20  53.60  87.74     180.0
# 732      EWR  2013      1   31    13  46.04  30.02  53.33     270.0
# 16546    JFK  2013     11   24    15  28.04  -0.04  29.16     310.0
# 9439     JFK  2013      1   31    12  51.80  46.40  81.74     270.0
# 9440     JFK  2013      1   31    13  46.94  30.02  51.55     270.0
# 9446     JFK  2013      1   31    19  42.98  17.06  34.81     260.0
# 18967    LGA  2013      3    6    16  41.00  33.98  75.88      70.0
# 18146    LGA  2013      1   31     8  55.40  53.60  93.65     180.0
# 9433     JFK  2013      1   31     6  53.06  51.08  92.96     180.0
# 16612    JFK  2013     11   27     9  60.98  59.00  93.19     170.0
# ...

# %% [markdown]
# ### The data set above shows that the windiest day at a New York City airport was February 12th, 2013 and it occurred at EWR - Newark Liberty International Airport.
